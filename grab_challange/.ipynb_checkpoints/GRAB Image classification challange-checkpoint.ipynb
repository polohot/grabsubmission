# %% [markdown]
# # GRAB IMAGE CHALLANGE SOLUTION

# %% [markdown]
# This notebook is setup in the google cloud platform<br>
# using NVIDIA TESLA P100 as the main training device<br>

# %% [markdown]
# **Dataset**<br>
# We are going to make the prediction of cars from the dataset provided by Grab team<br>
# 1. Link: https://ai.stanford.edu/~jkrause/cars/car_dataset.html <br>
# 2. Paper: [3D Object Representations for Fine-Grained Categorization](https://ai.stanford.edu/~jkrause/papers/3drr13.pdf)
# <img src="http://drive.google.com/uc?export=view&id=1gtvEPrkwFoJwz08QQfksx6NNqk4INcai">
# This is about 6 years ago, They have achieved best accuracy for the 196 classes prediction of **69.5%** <br>
# **Let see if we can do better!**

# %% [markdown]
# # FAST-AI LIBRARY
# Fast-AI library has been my main package for the past year, not only it is easy to use but it does includes <br>
# all the cutting edge technology for machine learning, also it get updated often <br>
# for this data-set we will follow some of the guidelines provided by Jeremy Howard (FAST-AI) <br>

# %%
# Import library dependencies
import numpy as np
import pandas as pd
import scipy.io
import my_function as mf
from os import listdir
from os.path import isfile, join
from PIL import Image as PILImage
# Import Fast.ai Library
import fastai as fastai
from fastai.vision import *
from fastai.metrics import error_rate
pd.options.mode.chained_assignment = None

# %% [markdown]
# **gpu checker**

# %%
# check if GPU is avialiable for training
print ('Is cuda avialiable = ', torch.cuda.is_available())
print ('Is cudnn avialiable = ', torch.backends.cudnn.enabled)
print ('Available devices = ', torch.cuda.device_count())
print ('Current cuda device number = ', torch.cuda.current_device())
print ('Current cuda device name = ', torch.cuda.get_device_name(0))
# Out:
# Is cuda avialiable =  True
# Is cudnn avialiable =  True
# Available devices =  1
# Current cuda device number =  0
# Current cuda device name =  GeForce GTX 950M

# %%
# run this line if there is no GPU
#defaults.device = torch.device('cpu')

# %% [markdown]
# # Data Preperation

# %%
# We will import the mat files and convert to dataframe
mat_anno = scipy.io.loadmat('data/cars_annos.mat')

df_all = pd.DataFrame(np.hstack((mat_anno['annotations'])))
df_map = pd.DataFrame(np.hstack((mat_anno['class_names'])))

# %%
# show test=0 and test=1
df_all[44:46]
# Out:
#         relative_im_path bbox_x1 bbox_y1  bbox_x2  bbox_y2  class   test
# 44  [car_ims/000045.jpg]   [[6]]   [[7]]   [[94]]   [[68]]  [[1]]  [[0]]
# 45  [car_ims/000046.jpg]  [[14]]  [[16]]  [[268]]  [[169]]  [[1]]  [[1]]

# %%
# This function will split the into train and test set on "test" column
df_trn,df_tst = mf.make_tst_trn(df_all)

# %%
df_trn.head(3)
# Out:
#                  name  cat
# 0  car_ims/000001.jpg    1
# 1  car_ims/000002.jpg    1
# 2  car_ims/000003.jpg    1

# %%
df_tst.head(3)
# Out:
#                  name  cat
# 0  car_ims/000046.jpg    1
# 1  car_ims/000047.jpg    1
# 2  car_ims/000048.jpg    1

# %%
# Next we will add the car name using mapper "df_map"
df_map.head(3)
# Out:
#                               0
# 0  [AM General Hummer SUV 2000]
# 1         [Acura RL Sedan 2012]
# 2         [Acura TL Sedan 2012]

# %%
# map category to the car name
df_trn['label'] = mf.make_label(df_trn,df_map)
df_tst['label'] = mf.make_label(df_tst,df_map)

# %%
df_trn.head(3)
# Out:
#                  name  cat                       label
# 0  car_ims/000001.jpg    1  AM General Hummer SUV 2000
# 1  car_ims/000002.jpg    1  AM General Hummer SUV 2000
# 2  car_ims/000003.jpg    1  AM General Hummer SUV 2000

# %%
df_tst.head(3)
# Out:
#                  name  cat                       label
# 0  car_ims/000046.jpg    1  AM General Hummer SUV 2000
# 1  car_ims/000047.jpg    1  AM General Hummer SUV 2000
# 2  car_ims/000048.jpg    1  AM General Hummer SUV 2000

# %%
df_trn = df_trn.reset_index(drop=True)
df_tst = df_tst.reset_index(drop=True)

df_trn_bkup = df_trn.copy()
df_tst_bkup = df_tst.copy()

# %% [markdown]
# # 1 - Feature Engineering

# %% [markdown]
# ## 1a - Image crop with openCV - See better when looking closer

# %% [markdown]
# Lastest research from **march 2019** on this car dataset <br>
# https://arxiv.org/pdf/1901.09891v2.pdf<br>
# <img src="http://drive.google.com/uc?export=view&id=1xgQKsomcWNvA3B-m8hV5-NcjkbgZO90d">
# **Research paper conclusion**<br>
# Better result if instead of using the whole image, we crop the car first<br>
# this will provide deeper feature to be trained on<br>
# Research accuracy on this dataset (stanford car) = **94.5%**

# %% [markdown]
# **We will use openCV library to crop the image**<br>
# This library provide pretrained model on top of openCV library<br>
# Link: https://towardsdatascience.com/object-detection-with-10-lines-of-code-d6cb4d86f606<br>
# <br>
# <img src="http://drive.google.com/uc?export=view&id=1WzC6ZWrMrm3K3ihDUCNG6Akcrv1pZJsK">

# %% [markdown]
# I have done cropping in my personal computer, this is th function if you want to try<br>
# The cropped image will be deposited into **car_crop_demo** folder<br>
# It's gonna take quite some time

# %%
# Takes hours
#create_cropped_data_and_save_in_folder(df_trn)

# %%
# df_trn2 is for the cropped image
df_trn2 = df_trn.copy()
df_trn2['name'] = df_trn2['name'].str.slice_replace(0, 8, 'car_crop/')

# %% [markdown]
# ## 1b - Image cleaning - mask out anything that could confuse the model<br>
# To make sure less noise is introduced during training, we will mask out other car in the training set<br>
# I did this on my laptop with photoshop, alternately you can use AI > image segmentation to automate this process<br>
# but for competition sake, I feel better that I do this my self<br>
# <img src="http://drive.google.com/uc?export=view&id=14-zUBNQonvUmIFu-QBX_S4FOus5jxLIW">

# %% [markdown]
# ## 1c - Image Augmentation (Feature engineering)
# We gonna use the get_transforms method provided by the fast.ai libraray<br>
# It bascially take the original image and transforms it into more images<br>
# For example **stretching, zooming, rotating** so if you input one cat image it will create something like this<br>
# This will provide more feature for the training set<br>
# [Source](https://docs.fast.ai/vision.transform.html)<br>
# <img src="http://drive.google.com/uc?export=view&id=1PuSVyTsoT5Fv5MGhGEFWSWWdnY6jnew5">

# %% [markdown]
# With this function you can preset how you want the image to be transformmed<br>
# <br>
# do_flip : flipping image horizontally = Yes, car can be coming from left and right, that makes sense<br>
# flip_vert: flipping image vertically = No need, unless you are tryinng to predict an upsidedown car<br>
# <br>
# We will leave other settings to the default

# %%
# initiate image transforming function
tfms = get_transforms(do_flip=True,       
                      flip_vert=False)

# %% [markdown]
# ## 1d - Create dataset for train and test<br>

# %% [markdown]
# **Join original data with cropped data**<br>
# This will add more training data for the model<br>
# This is intentional and will overfit the model to get the best accuracy on test set

# %%
# mf.make_databunch only takes 2 columns
df_trn = df_trn[['name','label']]
df_trn2 = df_trn2[['name','label']]
df_tst = df_tst[['name','label']]

# %%
# Join original data with cropped data
df_trn_all = df_trn.append(df_trn2).reset_index(drop=True)

# %% [markdown]
# <img src="http://drive.google.com/uc?export=view&id=1SWNo2JgvjxRsWrEWITi5YZxeDNwrrmhp">

# %% [markdown]
# # 2 - Train the model
# **Here I will demonstrate traditional and competition approach**<br>
# 1. Traditional approach = Split **traning set** into **traning(80%)** and **validation(20%)** set<br>
# 2. Competition approach = Use whole **training set** for training, use **test set** for validation<br>

# %% [markdown]
# ## 2.1 - Traditional Approach

# %%
# Load traning image and split 20% for validation
path='data/'
np.random.seed(0)
src = ImageList.from_df(path=path, df=df_trn_all).split_by_rand_pct(0.2).label_from_df()
src_test = ImageList.from_df(path=path, df=df_tst).split_none().label_from_df()

# %%
# Add test image into test set
src.test = src_test.train

# %%
# resize all to 64px and put all traning data into a class called "databunch"
sz=64 # image size
bs=64 # batch size
data = src.transform(tfms,size=sz).databunch(bs=bs)

# %%
# our data structure
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (13031 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# AM General Hummer SUV 2000,AM General Hummer SUV 2000,AM General Hummer SUV 2000,AM General Hummer SUV 2000,AM General Hummer SUV 2000
# Path: data;
#
# Valid: LabelList (3257 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# Jeep Grand Cherokee SUV 2012,Mercedes-Benz SL-Class Coupe 2009,BMW M5 Sedan 2010,Suzuki SX4 Sedan 2012,Ford F-150 Regular Cab 2012
# Path: data;
#
# Test: LabelList (8041 items)
# x: ImageList
# Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64),Image (3, 64, 64)
# y: CategoryList
# AM General Hummer SUV 2000,AM General Hummer SUV 2000,AM General Hummer SUV 2000,AM General Hummer SUV 2000,AM General Hummer SUV 2000
# Path: data

# %%
# Show some images in our data
data.show_batch(rows=3, figsize=(14,5))

# %% [markdown]
# ## Use pretrained model (Resnet architecture)<br>
# Instead of building and training the whole model from the beginning (normally I use keras CNN to do that)<br>
# **fast.ai** library has a function that we can download pretrained model from pytorch site<br>
# Now because resnet is a **pretrained model** on lots of image data by google <br>
# It does already recognize the features of objects of the human world <br>
# <br>
# I have tried from 18 34 50 101 and 152, for best accuracy in the competition<br>
# We will go with **resnet152** because we can hope to catch the most features<br>
# In the realworld, we can get more training data and we can use smaller resnet for optimizing speed

# %% [markdown]
# **Example of resnet34 layer >>** <br>
# <img src="http://drive.google.com/uc?export=view&id=1w7QoCe4t-I_E5LUWAoUGt60u6Z3VcDS4">

# %%
# define model
learn152 = cnn_learner(data, models.resnet152, metrics=[accuracy,error_rate])

# %%
# set default lr
lr = 1e-3

# %%
learn152.fit_one_cycle(6,max_lr=lr)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.594136</td>
#       <td>5.092262</td>
#       <td>0.041756</td>
#       <td>0.958244</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.898858</td>
#       <td>4.409943</td>
#       <td>0.096101</td>
#       <td>0.903899</td>
#       <td>01:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.298731</td>
#       <td>3.884025</td>
#       <td>0.162419</td>
#       <td>0.837581</td>
#       <td>01:31</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.824879</td>
#       <td>3.546400</td>
#       <td>0.216150</td>
#       <td>0.783850</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.522294</td>
#       <td>3.367344</td>
#       <td>0.247774</td>
#       <td>0.752226</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.368921</td>
#       <td>3.360389</td>
#       <td>0.247774</td>
#       <td>0.752226</td>
#       <td>01:31</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Learning Rate Annealing (fit_one_cycle)<br>
#
# Normally we train the model using constant learning rate <br>
# For this model we will fit the model using method called **"fit_one_cycle"** <br>
# The model will be fitted with **increasing learning rate to max_lr then the learning rate will decrease**<br>
# [Source](https://github.com/hiromis/notes/blob/master/Lesson3.md)<br>

# %%
# plot learning rate
learn152.recorder.plot_lr()

# %% [markdown]
# ## Unfreeze the pretrained model

# %% [markdown]
# The training above is just for the **few last layers** of resnet <br>
# We would want to fine tune all of the layers to recognize our cars model better<br>
# We can do that by **unfreeze** all the layers to be trainable <br>

# %%
# unfreeze all layers for training
learn152.unfreeze()

# %%
# Fit with lower learning rate
learn152.fit_one_cycle(6,max_lr=slice(lr/1000,lr/10))
learn152.save('152_64')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.323117</td>
#       <td>3.287600</td>
#       <td>0.258213</td>
#       <td>0.741787</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.242792</td>
#       <td>3.151703</td>
#       <td>0.279398</td>
#       <td>0.720602</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.086039</td>
#       <td>3.028037</td>
#       <td>0.301504</td>
#       <td>0.698496</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.956662</td>
#       <td>2.951003</td>
#       <td>0.318084</td>
#       <td>0.681916</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.866822</td>
#       <td>2.916082</td>
#       <td>0.322690</td>
#       <td>0.677310</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.831109</td>
#       <td>2.918559</td>
#       <td>0.322997</td>
#       <td>0.677003</td>
#       <td>01:55</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test set accuracy
print(mf.calc_accuracy(learn152,df_tst))
# Out:
# 2000 0.217
# 4000 0.21825
# 6000 0.23333333333333334
# 8000 0.244
# 0.2453674916055217

# %% [markdown]
# Validation accuracy = 32.2% / Test accuracy = 24.5%

# %% [markdown]
# Test accuracy is less, due to over fit from duplicate data<br>
# But we will allow this because we know enforced duplication when creating train dataset<br>
#
# We now have a model that is about **24.5%** accurate which is **really bad**, maybe the image **64x64px** is too small<br>
# Let's see what we can do next

# %% [markdown]
# ## Progressive resizing
# This is the concept of training the model with low resolution at first<br>
# Then gradually increased resolution and fit into the model again<br>
# [Source](https://towardsdatascience.com/boost-your-cnn-image-classifier-performance-with-progressive-resizing-in-keras-a7d96da06e20)<br>
# **Something like this**<br>
# <img src="http://drive.google.com/uc?export=view&id=1TKKkLY269Z0oYO2v8DxCQDB9i-42w-kk">
# <br>
# We can also use a hi-res image from the beginning,<br>
# But this method has proven to generalize the model better and **reduce over-fitting**<br><br>
# Now we will use the same model but train with new data<br>
# In this case **upsize the image from 64px to 96px**<br>
# For the model perspective, **this is a totally new dataset** so it is like we are adding new data be avialiable to be trained

# %%
sz=96; bs=64; cycle=6
#learn152.load('152_64')
learn152 = mf.transfer_learner(src,learn152,tfms,sz,bs,cycle,lr=lr)
learn152.save('152_96')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.749055</td>
#       <td>2.580418</td>
#       <td>0.394842</td>
#       <td>0.605158</td>
#       <td>02:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.550589</td>
#       <td>2.305111</td>
#       <td>0.433221</td>
#       <td>0.566779</td>
#       <td>02:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.193411</td>
#       <td>1.988214</td>
#       <td>0.490636</td>
#       <td>0.509364</td>
#       <td>02:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.911810</td>
#       <td>1.733355</td>
#       <td>0.552963</td>
#       <td>0.447037</td>
#       <td>02:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.644687</td>
#       <td>1.595423</td>
#       <td>0.582131</td>
#       <td>0.417869</td>
#       <td>02:18</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.559540</td>
#       <td>1.569500</td>
#       <td>0.587350</td>
#       <td>0.412650</td>
#       <td>02:17</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.505269</td>
#       <td>1.528082</td>
#       <td>0.599325</td>
#       <td>0.400675</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.473417</td>
#       <td>1.447758</td>
#       <td>0.616518</td>
#       <td>0.383482</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.359357</td>
#       <td>1.364781</td>
#       <td>0.637396</td>
#       <td>0.362604</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.230284</td>
#       <td>1.310845</td>
#       <td>0.655204</td>
#       <td>0.344796</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.171193</td>
#       <td>1.273936</td>
#       <td>0.658581</td>
#       <td>0.341418</td>
#       <td>03:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.131583</td>
#       <td>1.275902</td>
#       <td>0.657353</td>
#       <td>0.342647</td>
#       <td>03:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test set accuracy
print(mf.calc_accuracy(learn152,df_tst))
# Out:
# 2000 0.4685
# 4000 0.5035
# 6000 0.5325
# 8000 0.544125
# 0.5452058201716204

# %%
# Upsize to 144px
sz=144; bs=64; cycle=6
learn152 = mf.transfer_learner(src,learn152,tfms,sz,bs,cycle,lr=1e-3)
learn152.save('152_144')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.177230</td>
#       <td>1.084948</td>
#       <td>0.720909</td>
#       <td>0.279091</td>
#       <td>04:37</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.208058</td>
#       <td>1.078194</td>
#       <td>0.705864</td>
#       <td>0.294136</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.068972</td>
#       <td>0.964137</td>
#       <td>0.732576</td>
#       <td>0.267424</td>
#       <td>04:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.876500</td>
#       <td>0.806209</td>
#       <td>0.775253</td>
#       <td>0.224747</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.722970</td>
#       <td>0.710168</td>
#       <td>0.800737</td>
#       <td>0.199263</td>
#       <td>04:26</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.635631</td>
#       <td>0.698581</td>
#       <td>0.805342</td>
#       <td>0.194658</td>
#       <td>04:25</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.622377</td>
#       <td>0.683875</td>
#       <td>0.809948</td>
#       <td>0.190052</td>
#       <td>05:58</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.629003</td>
#       <td>0.653566</td>
#       <td>0.820694</td>
#       <td>0.179306</td>
#       <td>05:56</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.556140</td>
#       <td>0.613086</td>
#       <td>0.827142</td>
#       <td>0.172858</td>
#       <td>05:55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.510097</td>
#       <td>0.585564</td>
#       <td>0.833282</td>
#       <td>0.166718</td>
#       <td>05:56</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.444015</td>
#       <td>0.569100</td>
#       <td>0.838502</td>
#       <td>0.161498</td>
#       <td>05:56</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.438634</td>
#       <td>0.567719</td>
#       <td>0.838195</td>
#       <td>0.161805</td>
#       <td>05:55</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test set accuracy
print(mf.calc_accuracy(learn152,df_tst))
# Out:
# 2000 0.692
# 4000 0.7195
# 6000 0.7365
# 8000 0.74875
# 0.7492849148115907

# %% [markdown]
# **Accuracy better than methods in research paper**<br>
# Our test set accuracy is now 74.9% better than 69.5% from the 2012 research paper<br>
# And we took around 1 hour to train the resnet152 model to this point!

# %%
# Upsize to 216px
sz=216; bs=32; cycle=6
#learn152.load('152_144')
learn152 = mf.transfer_learner(src,learn152,tfms,sz,bs,cycle,lr=1e-3)
learn152.save('152_216')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.683574</td>
#       <td>0.614324</td>
#       <td>0.827449</td>
#       <td>0.172551</td>
#       <td>09:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.834764</td>
#       <td>0.678201</td>
#       <td>0.813632</td>
#       <td>0.186368</td>
#       <td>09:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.822030</td>
#       <td>0.618985</td>
#       <td>0.830212</td>
#       <td>0.169788</td>
#       <td>09:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.602884</td>
#       <td>0.490506</td>
#       <td>0.854467</td>
#       <td>0.145533</td>
#       <td>09:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.444977</td>
#       <td>0.410229</td>
#       <td>0.875959</td>
#       <td>0.124041</td>
#       <td>09:11</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.387786</td>
#       <td>0.396859</td>
#       <td>0.881486</td>
#       <td>0.118514</td>
#       <td>09:11</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.356623</td>
#       <td>0.393307</td>
#       <td>0.888855</td>
#       <td>0.111145</td>
#       <td>12:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.387778</td>
#       <td>0.392036</td>
#       <td>0.886399</td>
#       <td>0.113601</td>
#       <td>12:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.340596</td>
#       <td>0.365310</td>
#       <td>0.888855</td>
#       <td>0.111145</td>
#       <td>12:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.289529</td>
#       <td>0.333523</td>
#       <td>0.903592</td>
#       <td>0.096408</td>
#       <td>12:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.222357</td>
#       <td>0.314282</td>
#       <td>0.904513</td>
#       <td>0.095487</td>
#       <td>12:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.226685</td>
#       <td>0.313193</td>
#       <td>0.904820</td>
#       <td>0.095180</td>
#       <td>12:16</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test set accuracy
print(mf.calc_accuracy(learn152,df_tst))
# Out:
# 2000 0.789
# 4000 0.80825
# 6000 0.8293333333333334
# 8000 0.839125
# 0.8393234672304439

# %%
# Upsize to 324px
sz=324; bs=16; cycle=6
learn152 = mf.transfer_learner(src,learn152,tfms,sz,bs,cycle,lr=5e-4)
learn152.save('152_324')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.454433</td>
#       <td>0.373399</td>
#       <td>0.888241</td>
#       <td>0.111759</td>
#       <td>20:58</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.534028</td>
#       <td>0.403827</td>
#       <td>0.879951</td>
#       <td>0.120049</td>
#       <td>20:53</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.534692</td>
#       <td>0.364609</td>
#       <td>0.889469</td>
#       <td>0.110531</td>
#       <td>21:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.439846</td>
#       <td>0.319675</td>
#       <td>0.903592</td>
#       <td>0.096408</td>
#       <td>20:57</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.309743</td>
#       <td>0.286524</td>
#       <td>0.912496</td>
#       <td>0.087504</td>
#       <td>20:58</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.282299</td>
#       <td>0.277060</td>
#       <td>0.914338</td>
#       <td>0.085662</td>
#       <td>20:54</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.269909</td>
#       <td>0.280223</td>
#       <td>0.913110</td>
#       <td>0.086890</td>
#       <td>27:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.294981</td>
#       <td>0.277627</td>
#       <td>0.915566</td>
#       <td>0.084434</td>
#       <td>27:36</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.276185</td>
#       <td>0.264792</td>
#       <td>0.921707</td>
#       <td>0.078293</td>
#       <td>27:36</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.248803</td>
#       <td>0.243729</td>
#       <td>0.923549</td>
#       <td>0.076451</td>
#       <td>27:37</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.205256</td>
#       <td>0.238857</td>
#       <td>0.930918</td>
#       <td>0.069082</td>
#       <td>27:24</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.178056</td>
#       <td>0.236316</td>
#       <td>0.927234</td>
#       <td>0.072766</td>
#       <td>27:27</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test set accuracy
print(mf.calc_accuracy(learn152,df_tst))
# Out:
# 2000 0.8335
# 4000 0.85
# 6000 0.8728333333333333
# 8000 0.88175
# 0.8818554906106205

# %%
# Upsize to 486px
sz=486; bs=16; cycle=6
learn152 = mf.transfer_learner(src,learn152,tfms,sz,bs,cycle,lr=5e-4)
learn152.save('152_486')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.391411</td>
#       <td>0.340865</td>
#       <td>0.898680</td>
#       <td>0.101320</td>
#       <td>09:54</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.488279</td>
#       <td>0.366000</td>
#       <td>0.893460</td>
#       <td>0.106540</td>
#       <td>09:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.428648</td>
#       <td>0.335611</td>
#       <td>0.901750</td>
#       <td>0.098250</td>
#       <td>09:44</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.369225</td>
#       <td>0.283798</td>
#       <td>0.918330</td>
#       <td>0.081670</td>
#       <td>09:45</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.278469</td>
#       <td>0.252557</td>
#       <td>0.924163</td>
#       <td>0.075837</td>
#       <td>09:45</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.241937</td>
#       <td>0.244504</td>
#       <td>0.926006</td>
#       <td>0.073994</td>
#       <td>09:44</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.230987</td>
#       <td>0.249622</td>
#       <td>0.922321</td>
#       <td>0.077679</td>
#       <td>13:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.254753</td>
#       <td>0.256452</td>
#       <td>0.921707</td>
#       <td>0.078293</td>
#       <td>13:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.200094</td>
#       <td>0.232625</td>
#       <td>0.931839</td>
#       <td>0.068161</td>
#       <td>13:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.181464</td>
#       <td>0.224665</td>
#       <td>0.934602</td>
#       <td>0.065398</td>
#       <td>13:04</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.174962</td>
#       <td>0.209432</td>
#       <td>0.938594</td>
#       <td>0.061406</td>
#       <td>13:04</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.169256</td>
#       <td>0.210379</td>
#       <td>0.940436</td>
#       <td>0.059564</td>
#       <td>13:04</td>
#     </tr>
#   </tbody>
# </table>

# %%
# test set accuracy
print(mf.calc_accuracy(learn152,df_tst))
# Out:
# 2000 0.85
# 4000 0.866
# 6000 0.8898333333333334
# 8000 0.900125
# 0.9006342494714588

# %%
learn152.export('export152_486.pkl')

# %% [markdown]
# Final test set accuracy = 90.06%

# %% [markdown]
# ## 2.2 - Competition Approach
# Competition approach = Use whole **training set** for training, use **test set** for validation<br>
# We can use the validation accuracy directly to detemine the test accuracy, as it is the test set

# %%
# Load training image and test image
path='data/'
np.random.seed(0)
src_all = ImageList.from_df(path=path, df=df_trn_all).split_none().label_from_df()
src_test = ImageList.from_df(path=path, df=df_tst).split_none().label_from_df()

# %%
# Add test image into validation set
src_all.valid = src_test.train

# %%
# Resize all pictures to 64 px
sz=486 # image size
bs=64 # batch size
data_all = src_all.transform(tfms,size=sz).databunch(bs=bs)

# %%
# Define model
learn152_all = cnn_learner(data_all, models.resnet152, metrics=[accuracy,error_rate])

# %%
learn152_all.data = data_all

# %%
lr = 1e-3

# %%
sz=64; bs=64; cycle=5
learn152_all = mf.transfer_learner(src_all,learn152_all,tfms,sz,bs,cycle,lr=lr)
learn152_all.save('152_all_64')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.414823</td>
#       <td>5.062272</td>
#       <td>0.042656</td>
#       <td>0.957344</td>
#       <td>01:36</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.599846</td>
#       <td>4.358738</td>
#       <td>0.099988</td>
#       <td>0.900012</td>
#       <td>01:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.990877</td>
#       <td>3.891674</td>
#       <td>0.151971</td>
#       <td>0.848029</td>
#       <td>01:34</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.549768</td>
#       <td>3.653605</td>
#       <td>0.191643</td>
#       <td>0.808357</td>
#       <td>01:36</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.396385</td>
#       <td>3.596726</td>
#       <td>0.194628</td>
#       <td>0.805372</td>
#       <td>01:35</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.311414</td>
#       <td>3.535906</td>
#       <td>0.205198</td>
#       <td>0.794802</td>
#       <td>01:38</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.163687</td>
#       <td>3.401927</td>
#       <td>0.229698</td>
#       <td>0.770302</td>
#       <td>01:38</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.017096</td>
#       <td>3.357665</td>
#       <td>0.245741</td>
#       <td>0.754259</td>
#       <td>01:36</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.910330</td>
#       <td>3.246958</td>
#       <td>0.256187</td>
#       <td>0.743813</td>
#       <td>01:39</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.845914</td>
#       <td>3.252064</td>
#       <td>0.260291</td>
#       <td>0.739709</td>
#       <td>01:37</td>
#     </tr>
#   </tbody>
# </table>

# %%
sz=96; bs=64; cycle=5
learn152_all = mf.transfer_learner(src_all,learn152_all,tfms,sz,bs,cycle,lr=lr)
learn152_all.save('152_all_96')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.665935</td>
#       <td>2.649869</td>
#       <td>0.364756</td>
#       <td>0.635244</td>
#       <td>01:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.357289</td>
#       <td>2.370340</td>
#       <td>0.403557</td>
#       <td>0.596443</td>
#       <td>01:44</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.054975</td>
#       <td>2.075943</td>
#       <td>0.473449</td>
#       <td>0.526551</td>
#       <td>01:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.696473</td>
#       <td>1.904870</td>
#       <td>0.508892</td>
#       <td>0.491108</td>
#       <td>01:44</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.561774</td>
#       <td>1.872727</td>
#       <td>0.519836</td>
#       <td>0.480164</td>
#       <td>01:43</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.554211</td>
#       <td>1.837529</td>
#       <td>0.529412</td>
#       <td>0.470588</td>
#       <td>01:49</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.463872</td>
#       <td>1.755733</td>
#       <td>0.540729</td>
#       <td>0.459271</td>
#       <td>01:49</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.344852</td>
#       <td>1.674378</td>
#       <td>0.566099</td>
#       <td>0.433901</td>
#       <td>01:49</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.210565</td>
#       <td>1.641385</td>
#       <td>0.574680</td>
#       <td>0.425320</td>
#       <td>01:49</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.167691</td>
#       <td>1.623766</td>
#       <td>0.580525</td>
#       <td>0.419475</td>
#       <td>01:49</td>
#     </tr>
#   </tbody>
# </table>

# %%
sz=144; bs=64; cycle=5
learn152_all = mf.transfer_learner(src_all,learn152_all,tfms,sz,bs,cycle,lr=lr)
learn152_all.save('152_all_144')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1
td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.176626</td>
#       <td>0.306594</td>
#       <td>0.921030</td>
#       <td>0.078970</td>
#       <td>18:40</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.137623</td>
#       <td>0.312886</td>
#       <td>0.919662</td>
#       <td>0.080338</td>
#       <td>18:39</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.126251</td>
#       <td>0.305164</td>
#       <td>0.920781</td>
#       <td>0.079219</td>
#       <td>18:39</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.123130</td>
#       <td>0.306175</td>
#       <td>0.922273</td>
#       <td>0.077727</td>
#       <td>18:38</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn152_all.export('export152_all_486.pkl')

# %% [markdown]
# Final test set accuracy = 92.22%

# %% [markdown]
# # 3 - Make predictions
# after trying both approach, I have chosen competition approach to submit due to higher accuracy on the test dataset<br>

# %% [markdown]
# **3.1 - Individual image prediction**

# %%
# load the model
learn = load_learner('data/','export152_all_486.pkl')
# run this line if no GPU
#defaults.device = torch.device('cpu')

# %%
# Individual image prediction
img = open_image('hold_out_images/0008.jpg')
pred_class,_,conf = learn.predict(img)

# %%
# show predicted category
pred_class
# Out:
# Category BMW M6 Convertible 2010

# %%
# show confident for each category
conf
# Out:
# tensor([3.2288e-11, 3.3572e-10, 1.7860e-10, 3.9358e-10, 9.7659e-08, 1.6510e-08,
#         9.8379e-09, 6.0402e-06, 6.6780e-11, 8.1719e-08, 4.6822e-09, 1.5527e-09,
#         4.9721e-11, 2.0579e-11, 4.5598e-10, 9.5477e-08, 5.9706e-12, 8.5874e-10,
#         1.0960e-07, 7.4061e-11, 3.3155e-10, 5.9919e-10, 1.2864e-10, 2.9945e-09,
#         2.8206e-09, 2.7846e-07, 6.7685e-11, 1.2012e-08, 1.0957e-07, 4.8955e-02,
#         2.6098e-07, 3.3682e-07, 1.2192e-08, 9.5103e-01, 4.7073e-08, 2.5941e-08,
#         1.2522e-08, 3.5153e-06, 8.7633e-11, 1.5943e-09, 7.1403e-08, 1.4588e-08,
#         3.4137e-08, 1.2169e-09, 2.8185e-08, 1.2870e-08, 1.0165e-08, 2.6325e-08,
#         6.0102e-09, 3.1276e-08, 1.4101e-09, 2.7602e-10, 1.2550e-10, 4.8443e-10,
#         4.5544e-07, 3.4470e-10, 2.5942e-08, 8.4735e-11, 9.7452e-11, 2.5449e-09,
#         9.4542e-11, 5.1154e-10, 9.9774e-09, 4.7498e-09, 4.6296e-10, 1.2282e-10,
#         3.1987e-09, 1.5739e-09, 9.1550e-10, 1.0737e-08, 1.6404e-10, 8.7200e-11,
#         1.1303e-09, 1.1769e-10, 1.0686e-10, 1.0812e-09, 1.8430e-10, 1.9085e-08,
#         3.1592e-09, 1.2547e-06, 4.0044e-10, 1.6761e-10, 1.4186e-12, 3.2148e-12,
#         6.8630e-10, 2.3548e-10, 3.9408e-11, 1.5533e-09, 6.8421e-12, 1.0213e-09,
#         2.8370e-11, 2.9169e-09, 3.1293e-10, 6.2624e-10, 3.9367e-10, 1.0355e-09,
#         6.9750e-11, 3.7091e-10, 4.1129e-11, 1.9805e-10, 1.9740e-08, 1.2930e-12,
#         1.0075e-07, 2.0183e-09, 7.6374e-09, 1.3171e-09, 3.7964e-10, 6.2665e-10,
#         4.5024e-11, 8.8933e-11, 1.9444e-10, 1.5989e-10, 1.4202e-09, 3.2673e-08,
#         7.7615e-12, 8.6240e-09, 8.4315e-10, 1.9192e-12, 3.2286e-10, 4.8210e-11,
#         1.2167e-11, 1.6611e-09, 7.8706e-11, 1.9672e-08, 6.7148e-09, 2.3514e-09,
#         3.5713e-09, 5.3083e-10, 1.4080e-09, 1.7785e-10, 4.7158e-08, 3.5376e-09,
#         1.3219e-11, 6.5297e-10, 3.7937e-12, 2.9562e-09, 3.2097e-09, 6.2906e-10,
#         1.2987e-09, 2.0490e-09, 5.6145e-07, 4.5313e-09, 3.4726e-08, 7.8367e-08,
#         1.1742e-09, 1.4410e-09, 4.2517e-08, 2.8448e-10, 1.5431e-08, 1.7528e-11,
#         6.9276e-11, 1.8352e-10, 9.3976e-09, 2.1639e-10, 8.4034e-09, 2.7345e-09,
#         5.5692e-08, 8.4068e-09, 1.1380e-08, 2.7914e-09, 6.7697e-08, 5.4342e-10,
#         2.3678e-09, 2.0957e-10, 3.3061e-10, 1.8271e-09, 3.0519e-09, 6.9466e-08,
#         1.5897e-09, 1.7163e-10, 5.7552e-10, 2.6001e-09, 2.4384e-10, 3.3808e-11,
#         9.0623e-10, 3.0677e-07, 6.7520e-11, 3.2915e-12, 1.1002e-10, 8.7666e-11,
#         3.8330e-10, 1.2689e-08, 3.2613e-11, 4.4488e-10, 9.5736e-08, 3.0035e-09,
#         3.4813e-08, 5.1819e-10, 4.0977e-11, 2.2893e-09, 1.5638e-09, 5.7121e-09,
#         1.0440e-08, 7.2744e-10, 7.2424e-10, 1.1829e-08])

# %% [markdown]
# **3.2 - Test set prediction**

# %%
# load the model
learn = load_learner('data/','export152_all_486.pkl')
# run this line if there is no GPU
#defaults.device = torch.device('cpu')

# %%
df_tst = mf.load_df_tst()

# %%
score, confident = mf.calc_accuracy2(learn,df_tst[:5])

# %%
# show confident for each class
confident
# Out:
#                 0             1             2             3             4
# 0    9.993339e-01  9.999985e-01  9.999846e-01  9.995829e-01  7.523528e-01
# 1    2.001539e-10  9.972329e-12  2.035539e-10  3.749706e-10  3.257218e-08
# 2    4.643981e-10  3.112041e-12  3.297911e-10  1.924430e-10  1.821205e-08
# 3    2.136028e-09  6.612083e-12  1.485436e-10  1.523948e-09  5.315997e-08
# 4    1.065463e-11  9.740754e-14  1.124637e-11  3.788792e-11  2.504019e-09
# 5    1.174130e-08  2.099855e-10  5.715541e-11  2.620049e-10  5.408984e-06
# 6    1.527809e-08  4.814189e-12  2.216289e-10  1.879872e-10  1.223714e-06
# 7    8.042160e-10  1.525751e-09  5.833410e-10  1.659296e-09  1.233232e-04
# 8    3.933808e-10  1.578068e-09  9.782065e-10  8.041280e-10  2.128522e-04
# 9    8.309557e-11  2.906794e-12  2.127733e-10  1.489889e-10  7.409252e-07
# 10   5.948787e-11  2.323178e-11  1.769354e-10  4.635518e-10  7.014202e-07
# 181  2.824226e-11  1.452242e-11  2.969785e-11  9.134255e-10  6.642887e-06
# 182  1.995741e-10  8.403291e-13  8.413379e-12  5.112665e-10  4.782675e-08
# 183  8.338970e-09  2.293910e-11  2.460645e-10  1.513566e-09  6.031767e-07
# 184  1.194097e-11  3.055523e-12  2.514907e-10  1.672159e-10  6.161991e-06
# 185  6.247107e-11  7.650018e-12  1.028404e-10  4.611989e-10  7.060993e-06
# 186  1.310611e-08  1.894734e-11  1.954738e-10  1.081830e-08  3.371947e-07
# 187  9.714825e-10  1.627712e-11  5.092649e-11  3.771132e-09  1.284982e-06
# 188  4.940439e-10  3.109752e-11  1.386868e-10  1.933574e-09  2.300316e-06
# 189  2.952656e-09  4.156233e-10  8.251377e-11  1.428467e-09  4.467745e-06
# 190  8.602475e-10  4.648395e-12  7.900636e-09  3.908971e-11  3.897420e-08
# 191  2.958976e-09  3.394257e-10  6.055866e-11  5.407180e-11  1.811846e-05
# 192  2.148609e-09  5.546118e-09  5.310500e-06  1.388872e-07  4.361606e-05
# 193  2.413063e-11  1.270281e-13  1.671108e-11  1.007948e-11  2.221754e-07
# 194  8.064859e-11  3.332399e-14  1.271327e-11  2.806524e-11  4.457076e-08
# 195  1.099741e-08  6.887785e-10  1.018555e-10  3.471076e-09  1.703813e-05
#
# [196 rows x 5 columns]

# %% [markdown]
# **3.3 - Hold out image prediction**<br>
# please put all images into **/hold_out_images/** directory

# %%
# lists of file in hold_out_images folder
file_lists = [f for f in listdir('hold_out_images') if isfile(join('hold_out_images', f))]
file_lists.sort()

# %%
# run image prediction
ls_prd = []
df_conf=pd.DataFrame()
for pic_name in file_lists:
    img = open_image('hold_out_images/'+str(pic_name))
    pred,_,conf = learn.predict(img)
    ls_prd.append(str(pred))
    df_conf[str(pic_name)] = pd.Series(conf)

# %%
# show predicted name
ls_prd
# Out:
# ['AM General Hummer SUV 2000',
#  'Bentley Continental GT Coupe 2007',
#  'Chevrolet Cobalt SS 2010',
#  'AM General Hummer SUV 2000',
#  'Aston Martin Virage Coupe 2012',
#  'Audi S5 Coupe 2012',
#  'BMW 3 Series Sedan 2012',
#  'BMW M6 Convertible 2010',
#  'Bentley Continental GT Coupe 2007',
#  'Chrysler PT Cruiser Convertible 2008',
#  'Ford GT Coupe 2006',
#  'HUMMER H3T Crew Cab 2010',
#  'Hyundai Genesis Sedan 2012',
#  'Land Rover Range Rover SUV 2012',
#  'Mercedes-Benz S-Class Sedan 2012',
#  'Rolls-Royce Phantom Drophead Coupe Convertible 2012',
#  'Tesla Model S Sedan 2012']

# %%
# show confident for each class
df_conf
# Out:
#          0001.jpg      0002.jpg  0003.jpg      0004.jpg      0005.jpg  \
# 0    9.946898e-01  5.527050e-10  0.000012  9.999048e-01  6.342999e-10
# 1    1.899340e-09  9.535180e-10  0.000017  1.761115e-10  2.843292e-10
# 2    1.151257e-09  4.426672e-07  0.008731  5.013019e-10  1.051547e-08
